# %%
import pandas as pd

# %%
sourse_file_name = input('Input source file name without format: ')
sourse_file = sourse_file + '.csv'
# Out:
# Input source file name without format: marathon_athlete_events

# %%
df = pd.read_csv(sourse_file)
df.head()
# Out:
# C:\Users\olcha\AppData\Local\Temp\ipykernel_14472\2734556523.py:1: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(sourse_file)
#        ID                                               Name     Sex   Age  \
# 0   96774  Myra Abigail "Abbie" Pratt (Pankhurst-, Wright...  Female  41.0
# 1  102589          Hedwiga Rosenbaumov (Austerlitz-, -Raabe)  Female  35.0
# 2  102589          Hedwiga Rosenbaumov (Austerlitz-, -Raabe)  Female  35.0
# 3   95906            Lida Peyton "Eliza" Pollock (McMillen-)  Female  63.0
# 4   95906            Lida Peyton "Eliza" Pollock (McMillen-)  Female  63.0
#
#    Height  Weight                   Team  NOC        Games  Year  Season  \
# 0     NaN     NaN          United States  USA  1900 Summer  1900  Summer
# 1     NaN     NaN  Bohemia/Great Britain  BOH  1900 Summer  1900  Summer
# 2     NaN     NaN                Bohemia  BOH  1900 Summer  1900  Summer
# ...

# %%
final_file_name = sourse_file_name + '.xlsx'
df.to_excel(final_file_name)
